# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Схема-базы-данных" data-toc-modified-id="Схема-базы-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Схема базы данных</a></span></li><li><span><a href="#Выполнение-заданий" data-toc-modified-id="Выполнение-заданий-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Выполнение заданий</a></span><ul class="toc-item"><li><span><a href="#Задание-1" data-toc-modified-id="Задание-1-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Задание 1</a></span></li><li><span><a href="#Задание-2" data-toc-modified-id="Задание-2-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Задание 2</a></span></li><li><span><a href="#Задание-3" data-toc-modified-id="Задание-3-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Задание 3</a></span></li><li><span><a href="#Задание-4" data-toc-modified-id="Задание-4-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Задание 4</a></span></li><li><span><a href="#Задание-5" data-toc-modified-id="Задание-5-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Задание 5</a></span></li><li><span><a href="#Задание-6" data-toc-modified-id="Задание-6-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Задание 6</a></span></li><li><span><a href="#Задание-7" data-toc-modified-id="Задание-7-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Задание 7</a></span></li><li><span><a href="#Задание-8" data-toc-modified-id="Задание-8-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span>Задание 8</a></span></li><li><span><a href="#Задание-9" data-toc-modified-id="Задание-9-2.9"><span class="toc-item-num">2.9&nbsp;&nbsp;</span>Задание 9</a></span></li><li><span><a href="#Задание-10" data-toc-modified-id="Задание-10-2.10"><span class="toc-item-num">2.10&nbsp;&nbsp;</span>Задание 10</a></span></li><li><span><a href="#Задание-11" data-toc-modified-id="Задание-11-2.11"><span class="toc-item-num">2.11&nbsp;&nbsp;</span>Задание 11</a></span></li><li><span><a href="#Задание-12" data-toc-modified-id="Задание-12-2.12"><span class="toc-item-num">2.12&nbsp;&nbsp;</span>Задание 12</a></span></li><li><span><a href="#Задание-13" data-toc-modified-id="Задание-13-2.13"><span class="toc-item-num">2.13&nbsp;&nbsp;</span>Задание 13</a></span></li><li><span><a href="#Задание-14" data-toc-modified-id="Задание-14-2.14"><span class="toc-item-num">2.14&nbsp;&nbsp;</span>Задание 14</a></span></li><li><span><a href="#Задание-15" data-toc-modified-id="Задание-15-2.15"><span class="toc-item-num">2.15&nbsp;&nbsp;</span>Задание 15</a></span></li><li><span><a href="#Задание-16" data-toc-modified-id="Задание-16-2.16"><span class="toc-item-num">2.16&nbsp;&nbsp;</span>Задание 16</a></span></li><li><span><a href="#Задание-17" data-toc-modified-id="Задание-17-2.17"><span class="toc-item-num">2.17&nbsp;&nbsp;</span>Задание 17</a></span></li><li><span><a href="#Задание-18" data-toc-modified-id="Задание-18-2.18"><span class="toc-item-num">2.18&nbsp;&nbsp;</span>Задание 18</a></span></li><li><span><a href="#Задание-19" data-toc-modified-id="Задание-19-2.19"><span class="toc-item-num">2.19&nbsp;&nbsp;</span>Задание 19</a></span></li><li><span><a href="#Задание-20" data-toc-modified-id="Задание-20-2.20"><span class="toc-item-num">2.20&nbsp;&nbsp;</span>Задание 20</a></span></li><li><span><a href="#Задание-21" data-toc-modified-id="Задание-21-2.21"><span class="toc-item-num">2.21&nbsp;&nbsp;</span>Задание 21</a></span></li><li><span><a href="#Задание-22" data-toc-modified-id="Задание-22-2.22"><span class="toc-item-num">2.22&nbsp;&nbsp;</span>Задание 22</a></span></li><li><span><a href="#Задание-23" data-toc-modified-id="Задание-23-2.23"><span class="toc-item-num">2.23&nbsp;&nbsp;</span>Задание 23</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Формирование SQL-запросов к базе данных

# %% [markdown]
# Проект подразумевает работу с базой данных под управлением СУБД PostgreSQL. База данных хранит информацию о венчурных фондах и инвестициях в компании-стартапы и основана на датасете Startup Investments, опубликованном на популярной платформе для соревнований по исследованию данных Kaggle.
#
# В проекте нужно проанализировать данные о фондах и инвестициях и написать запросы к базе. Всего необходимо выполнить 23 задания, сложность которых будет постепенно увеличиваться.
#
# Непосредственно SQL-запросы выполняются в специальном тренажёре, поэтому в файле данного проекта будут представлен только код этих запросов.

# %% [markdown]
# ## Схема базы данных

# %% [markdown]
# ![database_diagram.png](attachment:database_diagram.png)

# %% [markdown]
# ## Выполнение заданий

# %% [markdown]
# ### Задание 1

# %% [markdown]
# **Формулировка задания:**
#
# Посчитать, сколько компаний закрылось.
#
# **Код запроса:**
#
# ```postgreSQL
# SELECT COUNT(*)
# FROM company
# WHERE status='closed'
# ```

# %% [markdown]
# ### Задание 2

# %% [markdown]
# **Формулировка задания:**
#
# Отобразить количество привлечённых средств для новостных компаний США. Использовать данные из таблицы `company`. Отсортируйте таблицу по убыванию значений в поле `funding_total`.
#
# **Код запроса:**
#
# ```postgreSQL
# SELECT funding_total
# FROM company
# WHERE category_code='news'
#   AND country_code='USA'
# ORDER BY funding_total DESC
# ```

# %% [markdown]
# ### Задание 3

# %% [markdown]
# **Формулировка задания:**
#
# Найти общую сумму сделок по покупке одних компаний другими в долларах. Отобрать сделки, которые осуществлялись только за наличные с 2011 по 2013 год включительно.
#
# **Код запроса:**
#
# ```postgreSQL
# SELECT SUM(price_amount)
# FROM acquisition
# WHERE term_code='cash'
#   AND EXTRACT(YEAR FROM acquired_at::timestamp) IN (2011, 2012, 2013)
# ```

# %% [markdown]
# ### Задание 4

# %% [markdown]
# **Формулировка задания:**
#
# Отобразить имя, фамилию и названия аккаунтов людей в твиттере, у которых названия аккаунтов начинаются на 'Silver'.
#
# **Код запроса:**
#
# ```postgreSQL
# SELECT first_name,
#        last_name,
#        twitter_username
# FROM people
# WHERE twitter_username LIKE 'Silver%'
# ```

# %% [markdown]
# ### Задание 5

# %% [markdown]
# **Формулировка задания:**
#
# Вывести на экран всю информацию о людях, у которых названия аккаунтов в твиттере содержат подстроку 'money', а фамилия начинается на 'K'.
#
# **Код запроса:**
#
# ```postgreSQL
# SELECT *
# FROM people
# WHERE twitter_username LIKE '%money%'
#   AND last_name LIKE 'K%'
# ```

# %% [markdown]
# ### Задание 6

# %% [markdown]
# **Формулировка задания:**
#
# Для каждой страны отобразить общую сумму привлечённых инвестиций, которые получили компании, зарегистрированные в этой стране. Страну, в которой зарегистрирована компания, можно определить по коду страны. Отсортировать данные по убыванию суммы.
#
# **Код запроса:**
#
# ```postgreSQL
# SELECT country_code,
#        SUM(funding_total) AS total_fund
# FROM company
# GROUP BY country_code
# ORDER BY total_fund DESC
# ```

# %% [markdown]
# ### Задание 7

# %% [markdown]
# **Формулировка задания:**
#
# Составить таблицу, в которую войдёт дата проведения раунда, а также минимальное и максимальное значения суммы инвестиций, привлечённых в эту дату.
#
# Оставить в итоговой таблице только те записи, в которых минимальное значение суммы инвестиций не равно нулю и не равно максимальному значению.
#
# **Код запроса:**
#
# ```postgreSQL
# SELECT funded_at,
#        MIN(raised_amount),
#        MAX(raised_amount)
# FROM funding_round
# GROUP BY funded_at
# HAVING MIN(raised_amount)<> 0
#   AND MIN(raised_amount)<>MAX(raised_amount)
# ORDER BY funded_at
# ```

# %% [markdown]
# ### Задание 8

# %% [markdown]
# **Формулировка задания:**
#
# Создать поле с категориями:
# - для фондов, которые инвестируют в 100 и более компаний, назначьте категорию high_activity;
# - для фондов, которые инвестируют в 20 и более компаний до 100, назначьте категорию middle_activity;
# - если количество инвестируемых компаний фонда не достигает 20, назначить категорию low_activity.
#
# Отобразить все поля таблицы `fund` и новое поле с категориями.
#
# **Код запроса:**
#
# ```postgreSQL
# SELECT *,
#        CASE
#          WHEN invested_companies>=100 THEN 'high_activity'
#          WHEN invested_companies>=20 AND invested_companies<100 THEN 'middle_activity'
#          WHEN invested_companies<20 THEN 'low_activity'
#        END AS category
# FROM fund
# ```

# %% [markdown]
# ### Задание 9

# %% [markdown]
# **Формулировка задания:**
#
# Для каждой из категорий, назначенных в предыдущем задании, посчитать округлённое до ближайшего целого числа среднее количество инвестиционных раундов, в которых фонд принимал участие. Вывести на экран категории и среднее число инвестиционных раундов. Отсортировать таблицу по возрастанию среднего.
#
# **Код запроса:**
# ```postgreSQL
# WITH temp_tab AS (
#     SELECT *,
#            CASE
#                WHEN invested_companies>=100 THEN 'high_activity'
#                WHEN invested_companies>=20 THEN 'middle_activity'
#                ELSE 'low_activity'
#            END AS activity
#     FROM fund
#     )
#
# SELECT activity,
#        ROUND(AVG(investment_rounds), 0) AS avg_round
# FROM temp_tab
# GROUP BY activity
# ORDER BY avg_round
# ```

# %% [markdown]
# ### Задание 10

# %% [markdown]
# **Формулировка задания:**
#
# Проанализировать, в каких странах находятся фонды, которые чаще всего инвестируют в стартапы.
#
# Для каждой страны посчитать минимальное, максимальное и среднее число компаний, в которые инвестировали фонды этой страны, основанные с 2010 по 2012 год включительно. Исключить страны с фондами, у которых минимальное число компаний, получивших инвестиции, равно нулю.
#
# Выгрузить десять самых активных стран-инвесторов: отсортировать таблицу по среднему количеству компаний от большего к меньшему. Затем добавить сортировку по коду страны в лексикографическом порядке.
#
# **Код запроса:**
# ```postgreSQL
# SELECT country_code,
#        MIN(invested_companies) AS min_comp,
#        MAX(invested_companies) AS max_comp,
#        AVG(invested_companies) AS avg_comp
# FROM fund
# WHERE EXTRACT(YEAR FROM founded_at) IN (2010,2011,2012)
# GROUP BY country_code
# HAVING MIN(invested_companies)<>0
# ORDER BY avg_comp DESC,
#          country_code
# LIMIT 10
# ```

# %% [markdown]
# ### Задание 11

# %% [markdown]
# **Формулировка задания:**
#
# Отобразить имя и фамилию всех сотрудников стартапов. Добавить поле с названием учебного заведения, которое окончил сотрудник, если эта информация известна.
#
# **Код запроса:**
# ```postgreSQL
# SELECT p.first_name,
#        p.last_name,
#        e.instituition
# FROM people AS p
# LEFT OUTER JOIN education AS e ON p.id=e.person_id
# ```

# %% [markdown]
# ### Задание 12

# %% [markdown]
# **Формулировка задания:**
#
# Для каждой компании найти количество учебных заведений, которые окончили её сотрудники. Вывести название компании и число уникальных названий учебных заведений. Составить топ-5 компаний по количеству университетов.
#
# **Код запроса:**
# ```postgreSQL
# SELECT c.name,
#        COUNT(DISTINCT e.instituition) AS ins_count
# FROM company AS c
# INNER JOIN people AS p ON c.id=p.company_id
# INNER JOIN education AS e ON p.id=e.person_id
# GROUP BY c.name
# ORDER BY ins_count DESC
# LIMIT 5
# ```

# %% [markdown]
# ### Задание 13

# %% [markdown]
# **Формулировка задания:**
#
# Составить список с уникальными названиями закрытых компаний, для которых первый раунд финансирования оказался последним.
#
# **Код запроса:**
# ```postgreSQL
# SELECT DISTINCT c.name
# FROM company AS c
# INNER JOIN funding_round AS fr ON c.id=fr.company_id
# WHERE c.status='closed'
#   AND fr.is_first_round=1
#   AND fr.is_last_round=1
# ```

# %% [markdown]
# ### Задание 14

# %% [markdown]
# **Формулировка задания:**
#
# Составить список уникальных номеров сотрудников, которые работают в компаниях, отобранных в предыдущем задании.
#
# **Код запроса:**
# ```postgreSQL
# WITH company_list AS (
#     SELECT DISTINCT c.name
#     FROM company AS c
#     INNER JOIN funding_round AS fr ON c.id=fr.company_id
#     WHERE c.status='closed'
#       AND fr.is_first_round=1
#       AND fr.is_last_round=1
# )
#
# SELECT p.id
# FROM people AS p
# INNER JOIN company AS c ON p.company_id=c.id
# WHERE c.name IN (SELECT *
#                  FROM company_list)
# ```

# %% [markdown]
# ### Задание 15

# %% [markdown]
# **Формулировка задания:**
#
# Составить таблицу, куда войдут уникальные пары с номерами сотрудников из предыдущей задачи и учебным заведением, которое окончил сотрудник.
#
# **Код запроса:**
# ```postgreSQL
# WITH company_list AS (
#     SELECT DISTINCT c.name
#     FROM company AS c
#     INNER JOIN funding_round AS fr ON c.id=fr.company_id
#     WHERE c.status='closed'
#       AND fr.is_first_round=1
#       AND fr.is_last_round=1
# ),
#   people_list AS (
#     SELECT p.id
#     FROM people AS p
#     INNER JOIN company AS c ON p.company_id=c.id
#     WHERE c.name IN (SELECT *
#                      FROM company_list)
# )
#
# SELECT DISTINCT p.id,
#        e.instituition
# FROM people AS p
# INNER JOIN education AS e ON p.id=e.person_id
# WHERE p.id IN (SELECT *
#               FROM people_list)
# ```

# %% [markdown]
# ### Задание 16

# %% [markdown]
# **Формулировка задания:**
#
# Посчитать количество учебных заведений для каждого сотрудника из предыдущего задания. При подсчёте учесть, что некоторые сотрудники могли окончить одно и то же заведение дважды.
#
# **Код запроса:**
#
# ```postgreSQL
# WITH company_list AS (
#     SELECT DISTINCT c.name
#     FROM company AS c
#     INNER JOIN funding_round AS fr ON c.id=fr.company_id
#     WHERE c.status='closed'
#       AND fr.is_first_round=1
#       AND fr.is_last_round=1
# ),
#   people_list AS (
#     SELECT p.id
#     FROM people AS p
#     INNER JOIN company AS c ON p.company_id=c.id
#     WHERE c.name IN (SELECT *
#                      FROM company_list)
# )
#
# SELECT p.id,
#        COUNT(e.instituition) AS inst_count
# FROM people AS p
# INNER JOIN education AS e ON p.id=e.person_id
# WHERE p.id IN (SELECT *
#               FROM people_list)
# GROUP BY p.id
# ORDER BY p.id
# ```

# %% [markdown]
# ### Задание 17

# %% [markdown]
# **Формулировка задания:**
#
# Дополнить предыдущий запрос и выведите среднее число учебных заведений (всех, не только уникальных), которые окончили сотрудники разных компаний. Нужно вывести только одну запись, группировка здесь не понадобится.
#
# **Код запроса:**
# ```postgreSQL
# WITH company_list AS (
#     SELECT DISTINCT c.name
#     FROM company AS c
#     INNER JOIN funding_round AS fr ON c.id=fr.company_id
#     WHERE c.status='closed'
#       AND fr.is_first_round=1
#       AND fr.is_last_round=1
# ),
#   people_list AS (
#     SELECT p.id
#     FROM people AS p
#     INNER JOIN company AS c ON p.company_id=c.id
#     WHERE c.name IN (SELECT *
#                      FROM company_list)
# ),
#   instituition_list AS (
#     SELECT p.id,
#            COUNT(e.instituition) AS inst_count
#     FROM people AS p
#     INNER JOIN education AS e ON p.id=e.person_id
#     WHERE p.id IN (SELECT *
#                   FROM people_list)
#     GROUP BY p.id
#     ORDER BY p.id
# )
#
# SELECT AVG(inst_count)
# FROM instituition_list
# ```

# %% [markdown]
# ### Задание 18

# %% [markdown]
# **Формулировка задания:**
#
# Написать похожий запрос: вывести среднее число учебных заведений (всех, не только уникальных), которые окончили сотрудники Facebook.
#
# **Код запроса:**
# ```postgreSQL
# WITH instituition_list AS (
#     SELECT p.id,
#            COUNT(e.instituition) AS inst_count
#     FROM people AS p
#     INNER JOIN education AS e ON p.id=e.person_id
#     INNER JOIN company AS c ON p.company_id=c.id
#     WHERE c.name = 'Facebook'
#     GROUP BY p.id
#     ORDER BY p.id
# )
#
# SELECT AVG(inst_count)
# FROM instituition_list
# ```

# %% [markdown]
# ### Задание 19

# %% [markdown]
# **Формулировка задания:**
#
# Составить таблицу из полей:
# - `name_of_fund` — название фонда;
# - `name_of_company` — название компании;
# - `amount` — сумма инвестиций, которую привлекла компания в раунде.
# В таблицу войдут данные о компаниях, в истории которых было больше шести важных этапов, а раунды финансирования проходили с 2012 по 2013 год включительно.
#
# **Код запроса:**
# ```postgreSQL
# SELECT DISTINCT fd.name AS name_of_fund,
#                  c.name AS name_of_company,
#                  fr.raised_amount AS amount
# FROM fund AS fd
# INNER JOIN investment AS i ON fd.id=i.fund_id
# INNER JOIN company AS c ON i.company_id=c.id
# INNER JOIN funding_round AS fr ON i.funding_round_id=fr.id
# WHERE EXTRACT(YEAR FROM fr.funded_at) IN (2012, 2013)
#   AND c.milestones>6
# ```

# %% [markdown]
# ### Задание 20

# %% [markdown]
# **Формулировка задания:**
#
# Выгрузить таблицу, в которой будут такие поля:
# - название компании-покупателя;
# - сумма сделки;
# - название компании, которую купили;
# - сумма инвестиций, вложенных в купленную компанию;
# - доля, которая отображает, во сколько раз сумма покупки превысила сумму вложенных в компанию инвестиций, округлённая до ближайшего целого числа.
#
# Не учитывать те сделки, в которых сумма покупки равна нулю. Если сумма инвестиций в компанию равна нулю, исключить такую компанию из таблицы.
#
# Отсортировать таблицу по сумме сделки от большей к меньшей, а затем по названию купленной компании в лексикографическом порядке. Ограничить таблицу первыми десятью записями.
#
# **Код запроса:**
# ```postgreSQL
# WITH temp_tab1 AS (
#     SELECT c.name AS acquiring_comp,
#            a.price_amount,
#            a.acquired_company_id
#     FROM acquisition AS a
#     INNER JOIN company AS c ON a.acquiring_company_id=c.id
#     WHERE a.price_amount<>0
# ),
# temp_tab2 AS (
#     SELECT id AS acquired_comp_id,
#            funding_total AS total_fund
#     FROM company
#     WHERE status='acquired'
#       AND funding_total<>0
#     )
#
# SELECT tt1.acquiring_comp,
#        tt1.price_amount,
#        c.name AS acquired_comp,
#        tt2.total_fund,
#        ROUND(tt1.price_amount/tt2.total_fund,0) AS part
# FROM temp_tab1 AS tt1
# INNER JOIN temp_tab2 AS tt2 ON tt1.acquired_company_id=tt2.acquired_comp_id
# INNER JOIN company AS c ON tt1.acquired_company_id=c.id
# ORDER BY price_amount DESC,
#          acquired_comp
# LIMIT 10
# ```

# %% [markdown]
# ### Задание 21

# %% [markdown]
# **Формулировка задания:**
#
# Выгрузить таблицу, в которую войдут названия компаний из категории social, получившие финансирование с 2010 по 2013 год включительно. Проверить, что сумма инвестиций не равна нулю. Вывести также номер месяца, в котором проходил раунд финансирования.
#
# **Код запроса:**
# ```postgreSQL
# SELECT c.name,
#        EXTRACT(MONTH FROM fr.funded_at) AS month
# FROM company AS c
# INNER JOIN funding_round AS fr ON c.id=fr.company_id
# WHERE c.category_code='social'
#   AND EXTRACT(YEAR FROM fr.funded_at) BETWEEN 2010 AND 2013
#   AND fr.raised_amount<>0
# ```

# %% [markdown]
# ### Задание 22

# %% [markdown]
# **Формулировка задания:**
#
# Отобрать данные по месяцам с 2010 по 2013 год, когда проходили инвестиционные раунды. Сгруппировать данные по номеру месяца и получите таблицу, в которой будут поля:
# - номер месяца, в котором проходили раунды;
# - количество уникальных названий фондов из США, которые инвестировали в этом месяце;
# - количество компаний, купленных за этот месяц;
# - общая сумма сделок по покупкам в этом месяце.
#
# **Код запроса:**
# ```postgreSQL
# WITH temp_tab1 AS (
#     SELECT EXTRACT(MONTH FROM fr.funded_at) AS month,
#            COUNT(DISTINCT fd.name) AS fund_count
#     FROM funding_round AS fr
#     INNER JOIN investment AS i ON fr.id=i.funding_round_id
#     INNER JOIN fund AS fd ON i.fund_id=fd.id
#     WHERE fr.funded_at IS NOT NULL
#       AND EXTRACT(YEAR FROM fr.funded_at) BETWEEN 2010 AND 2013
#       AND fd.country_code='USA'
#     GROUP BY month
#     ORDER BY month
#     ),
# temp_tab2 AS (
#     SELECT EXTRACT(MONTH FROM acquired_at) AS month,
#            COUNT(acquired_company_id) AS comp_count,
#            SUM(price_amount) AS acq_sum
#     FROM acquisition
#     WHERE acquired_at IS NOT NULL
#       AND EXTRACT(YEAR FROM acquired_at) BETWEEN 2010 AND 2013
#     GROUP BY month
#     ORDER BY month
#     )
#
# SELECT tt1.month,
#        tt1.fund_count,
#        tt2.comp_count,
#        tt2.acq_sum
# FROM temp_tab1 AS tt1
# INNER JOIN temp_tab2 AS tt2 ON tt1.month=tt2.month
# ORDER BY tt1.month
# ```

# %% [markdown]
# ### Задание 23

# %% [markdown]
# **Формулировка задания:**
#
# Составить сводную таблицу и вывести среднюю сумму инвестиций для стран, в которых есть стартапы, зарегистрированные в 2011, 2012 и 2013 годах. Данные за каждый год должны быть в отдельном поле. Отсортировать таблицу по среднему значению инвестиций за 2011 год от большего к меньшему.
#
# **Код запроса:**
# ```postgreSQL
# with tt1 AS (
#     SELECT country_code,
#            AVG(funding_total) AS avg_2011
#     FROM company
#     WHERE EXTRACT(YEAR FROM founded_at) = 2011
#         AND country_code IS NOT NULL
#     GROUP BY country_code
#     ),
# tt2 AS (
#     SELECT country_code,
#            AVG(funding_total) AS avg_2012
#     FROM company
#     WHERE EXTRACT(YEAR FROM founded_at) = 2012
#         AND country_code IS NOT NULL
#     GROUP BY country_code
#     ),
# tt3 AS (
#     SELECT country_code,
#            AVG(funding_total) AS avg_2013
#     FROM company
#     WHERE EXTRACT(YEAR FROM founded_at) = 2013
#         AND country_code IS NOT NULL
#     GROUP BY country_code
#     )
#
# SELECT tt1.country_code,
#        tt1.avg_2011,
#        tt2.avg_2012,
#        tt3.avg_2013
# FROM tt1
# INNER JOIN tt2 ON tt1.country_code=tt2.country_code
# INNER JOIN tt3 ON tt1.country_code=tt3.country_code
# ORDER BY tt1.avg_2011 DESC
# ```
